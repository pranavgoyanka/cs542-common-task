# %%
import pandas as pd
import numpy as np

# %%
# Define some constants
latitude = [40.79736, 41.78701, 30.1444, 25.7738]
longitude = [-73.97785, -87.77166, -97.66876, -80.1936]
cities = ["ny", "il", "tx", "fl"]
start_date = "2016-01-01"
end_date = "2024-03-24"

# %%
# Unpickle the DataFrames
city_history_dfs = []

for i in range(len(cities)):
  city_history_dfs.append(pd.read_pickle("./Data/merged_df_" + cities[i] + ".pkl"))

print("Loaded DFs for " + str(len(city_history_dfs)) + " cities.\n")
# print(city_history_dfs[0].info())
print(city_history_dfs[0].tail())
# Out:
# Loaded DFs for 4 cities.
#
#             date  tmax_vc  tmin_vc  humi_vc  wind_vc  tmax_om  tmin_om  \
# 3001  2024-03-20     55.7     37.1     51.3     17.1   11.143    1.443
# 3002  2024-03-21     41.9     30.0     31.6     18.3    6.043   -3.457
# 3003  2024-03-22     43.5     29.0     41.4     12.4    5.943   -4.407
# 3004  2024-03-23     48.1     38.1     82.1     16.8    9.393    3.093
# 3005  2024-03-24     47.3     30.9     39.9     16.1      NaN      NaN
#
#         sund_om  prec_om    wind_om  ...  tmin_ncei  wt08_ncei  wt01_ncei  \
# 3001  26404.998      6.0  28.019936  ...       34.0        NaN        NaN
# 3002  40807.540      0.0  28.793250  ...       30.0        NaN        NaN
# 3003  37899.984      0.0  18.214718  ...        NaN        NaN        NaN
# 3004      0.000     17.0  32.553630  ...        NaN        NaN        NaN
# 3005        NaN      0.0        NaN  ...        NaN        NaN        NaN
#
#       wt02_ncei  wt06_ncei  wt04_ncei  tsun_ncei  pgtm_ncei  wt03_ncei  \
# 3001        NaN        NaN        NaN        NaN        NaN        NaN
# 3002        NaN        NaN        NaN        NaN     1212.0        NaN
# 3003        NaN        NaN        NaN        NaN        NaN        NaN
# 3004        NaN        NaN        NaN        NaN        NaN        NaN
# 3005        NaN        NaN        NaN        NaN        NaN        NaN
#
#       wt05_ncei
# 3001        NaN
# 3002        NaN
# 3003        NaN
# 3004        NaN
# 3005        NaN
#
# [5 rows x 48 columns]

# %%
for i in range(len(cities)):
  # Figure out what all cols to keep
  allCols = city_history_dfs[i].columns.tolist()
  print(len(allCols))
  print(*allCols, sep = '\n')
  # Keep the columns we need
  # date, tmax from all sources, 
  # humidity from visual crossing,
  # precipitation from open meteo,
  # snow from meteo stats
  # sunny time from ncei
  ny_data = city_history_dfs[i][['date', 'tmax_vc', 'tmax_om', 'tmax_ms', 'tmax_ncei', 'humi_vc', 'prec_om', 'tmin_ms', 'tmin_ncei']]
  # ny_data = city_history_dfs[i][['date', 'tmax_vc', 'tmax_om', 'tmax_ms', 'humi_vc', 'prec_om', 'tmin_ms', ]]
  ny_data.info()
  
  def cleanAndPreprocessData(df):
    columns_to_convert_to_farhenheit = ['tmax_om', 'tmax_ms', 'tmin_ms']
    for column in columns_to_convert_to_farhenheit:
      df[column] = df[column] * 9/5 + 32
    print(df.head())
    df['date'] = pd.to_datetime(df['date']) 
    df['day'] = df['date'].dt.dayofyear
    df['tmax_avg'] = df[['tmax_vc', 'tmax_om', 'tmax_ms' ]].mean(axis=1)
    df['tmin_avg'] = df[['tmin_ms']].mean(axis=1)
    return df

  ny_data = cleanAndPreprocessData(ny_data)
  ny_data.to_pickle("./Data/data_cleaned_"+ cities[i] +".pkl")
# Out:
# 48
# date
# tmax_vc
# tmin_vc
# humi_vc
# wind_vc
# tmax_om
# tmin_om
# sund_om
# prec_om
# wind_om
# tavg_ms
# tmin_ms
# tmax_ms
# prcp_ms
# snow_ms
# wdir_ms
# wspd_ms
# wpgt_ms
# pres_ms
# tsun_ms
# unnamed: 0_ncei
# wsf2_ncei
# station_ncei
# wsf5_ncei
# snow_ncei
# rhmx_ncei
# aslp_ncei
# prcp_ncei
# rhav_ncei
# snwd_ncei
# astp_ncei
# rhmn_ncei
# wdf2_ncei
# awnd_ncei
# wdf5_ncei
# awbt_ncei
# tmax_ncei
# adpt_ncei
# tmin_ncei
# wt08_ncei
# wt01_ncei
# wt02_ncei
# wt06_ncei
# wt04_ncei
# tsun_ncei
# pgtm_ncei
# wt03_ncei
# wt05_ncei
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3006 entries, 0 to 3005
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3006 non-null   object
#  1   tmax_vc    3006 non-null   float64
#  2   tmax_om    3005 non-null   float64
#  3   tmax_ms    1461 non-null   float64
#  4   tmax_ncei  3003 non-null   float64
#  5   humi_vc    3006 non-null   float64
#  6   prec_om    3006 non-null   float64
#  7   tmin_ms    1461 non-null   float64
#  8   tmin_ncei  3003 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 211.5+ KB
#          date  tmax_vc  tmax_om  tmax_ms  tmax_ncei  humi_vc  prec_om  \
# 0  2016-01-01     42.2   44.114      NaN       42.0     52.5      0.0
# 1  2016-01-02     39.8   39.884      NaN       40.0     47.4      0.0
# 2  2016-01-03     44.3   43.844      NaN       45.0     48.6      0.0
# 3  2016-01-04     36.1   35.744      NaN       36.0     46.4      0.0
# 4  2016-01-05     28.6   29.804      NaN       29.0     38.8      0.0
#
#    tmin_ms  tmin_ncei
# 0      NaN       34.0
# 1      NaN       32.0
# 2      NaN       35.0
# 3      NaN       14.0
# 4      NaN       11.0
# 42
# date
# tmax_vc
# tmin_vc
# humi_vc
# wind_vc
# tmax_om
# tmin_om
# sund_om
# prec_om
# wind_om
# tavg_ms
# tmin_ms
# tmax_ms
# prcp_ms
# snow_ms
# wdir_ms
# wspd_ms
# wpgt_ms
# pres_ms
# tsun_ms
# unnamed: 0_ncei
# wsf2_ncei
# wdf2_ncei
# awnd_ncei
# station_ncei
# wsf5_ncei
# wdf5_ncei
# pgtm_ncei
# tmax_ncei
# tmin_ncei
# prcp_ncei
# wt01_ncei
# wt08_ncei
# wt03_ncei
# wt02_ncei
# wt04_ncei
# wt09_ncei
# snow_ncei
# snwd_ncei
# wt06_ncei
# wt05_ncei
# wt10_ncei
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3006 entries, 0 to 3005
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3006 non-null   object
#  1   tmax_vc    3006 non-null   float64
#  2   tmax_om    3005 non-null   float64
#  3   tmax_ms    3006 non-null   float64
#  4   tmax_ncei  3002 non-null   float64
#  5   humi_vc    3006 non-null   float64
#  6   prec_om    3006 non-null   float64
#  7   tmin_ms    3006 non-null   float64
#  8   tmin_ncei  3002 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 211.5+ KB
#          date  tmax_vc  tmax_om  tmax_ms  tmax_ncei  humi_vc  prec_om  \
# 0  2016-01-01     30.8  30.3485    30.92       31.0     67.5      0.0
# 1  2016-01-02     33.2  34.2185    33.08       33.0     67.6      0.0
# 2  2016-01-03     30.8  31.2485    30.92       31.0     64.9      0.0
# 3  2016-01-04     32.0  31.5185    32.00       32.0     61.5      0.0
# 4  2016-01-05     34.1  34.4885    33.98       34.0     66.6      0.0
#
#    tmin_ms  tmin_ncei
# 0    19.94       20.0
# 1    21.92       22.0
# 2    24.08       24.0
# 3    24.98       25.0
# 4    21.02       21.0
# 50
# date
# tmax_vc
# tmin_vc
# humi_vc
# wind_vc
# tmax_om
# tmin_om
# sund_om
# prec_om
# wind_om
# tavg_ms
# tmin_ms
# tmax_ms
# prcp_ms
# snow_ms
# wdir_ms
# wspd_ms
# wpgt_ms
# pres_ms
# tsun_ms
# unnamed: 0_ncei
# wsf2_ncei
# station_ncei
# wsf5_ncei
# snow_ncei
# rhmx_ncei
# aslp_ncei
# prcp_ncei
# rhav_ncei
# snwd_ncei
# astp_ncei
# rhmn_ncei
# wdf2_ncei
# awnd_ncei
# wdf5_ncei
# awbt_ncei
# tmax_ncei
# adpt_ncei
# tavg_ncei
# tmin_ncei
# wt01_ncei
# wt03_ncei
# wt08_ncei
# wt02_ncei
# wt05_ncei
# wt07_ncei
# wt04_ncei
# pgtm_ncei
# wt06_ncei
# wt09_ncei
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3006 entries, 0 to 3005
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3006 non-null   object
#  1   tmax_vc    3006 non-null   float64
#  2   tmax_om    3005 non-null   float64
#  3   tmax_ms    3005 non-null   float64
#  4   tmax_ncei  3003 non-null   float64
#  5   humi_vc    3006 non-null   float64
#  6   prec_om    3006 non-null   float64
#  7   tmin_ms    3005 non-null   float64
#  8   tmin_ncei  3003 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 211.5+ KB
#          date  tmax_vc  tmax_om  tmax_ms  tmax_ncei  humi_vc  prec_om  \
# 0  2016-01-01     50.0  52.1159    50.00       50.0     61.5      0.0
# 1  2016-01-02     47.9  46.3559    48.02       48.0     65.7      6.0
# 2  2016-01-03     61.1  59.2259    60.98       61.0     75.5      9.0
# 3  2016-01-04     57.0  55.4459    57.92       58.0     67.0      0.0
# 4  2016-01-05     56.9  55.4459    57.02       57.0     74.9      0.0
#
#    tmin_ms  tmin_ncei
# 0    44.06       44.0
# 1    42.98       43.0
# 2    33.08       33.0
# 3    32.00       32.0
# 4    29.12       29.0
# 29
# date
# tmax_vc
# tmin_vc
# humi_vc
# wind_vc
# tmax_om
# tmin_om
# sund_om
# prec_om
# wind_om
# tavg_ms
# tmin_ms
# tmax_ms
# prcp_ms
# snow_ms
# wdir_ms
# wspd_ms
# wpgt_ms
# pres_ms
# tsun_ms
# unnamed: 0_ncei
# station_ncei
# tmax_ncei
# tmin_ncei
# prcp_ncei
# tobs_ncei
# wt03_ncei
# dapr_ncei
# mdpr_ncei
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3006 entries, 0 to 3005
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3006 non-null   object
#  1   tmax_vc    3006 non-null   float64
#  2   tmax_om    3005 non-null   float64
#  3   tmax_ms    3006 non-null   float64
#  4   tmax_ncei  2754 non-null   float64
#  5   humi_vc    3006 non-null   float64
#  6   prec_om    3006 non-null   float64
#  7   tmin_ms    3006 non-null   float64
#  8   tmin_ncei  2765 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 211.5+ KB
#          date  tmax_vc    tmax_om  tmax_ms  tmax_ncei  humi_vc  prec_om  \
# 0  2016-01-01     83.7  81.308300    84.02       83.0     79.2      1.0
# 1  2016-01-02     82.9  79.328298    84.02       83.0     79.2      9.0
# 2  2016-01-03     78.6  76.718300    78.98       82.0     85.8      7.0
# 3  2016-01-04     70.7  73.928298    71.06       82.0     66.5      3.0
# 4  2016-01-05     72.0  71.498300    71.96       72.0     67.3      0.0
#
#    tmin_ms  tmin_ncei
# 0    73.94       74.0
# 1    71.06       70.0
# 2    64.94       68.0
# 3    60.98       62.0
# 4    60.08       58.0
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column] * 9/5 + 32
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['date'].dt.dayofyear
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tmax_avg'] = df[['tmax_vc', 'tmax_om', 'tmax_ms' ]].mean(axis=1)
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tmin_avg'] = df[['tmin_ms']].mean(axis=1)
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column] * 9/5 + 32
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['date'].dt.dayofyear
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tmax_avg'] = df[['tmax_vc', 'tmax_om', 'tmax_ms' ]].mean(axis=1)
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tmin_avg'] = df[['tmin_ms']].mean(axis=1)
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column] * 9/5 + 32
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['date'].dt.dayofyear
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tmax_avg'] = df[['tmax_vc', 'tmax_om', 'tmax_ms' ]].mean(axis=1)
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tmin_avg'] = df[['tmin_ms']].mean(axis=1)
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column] * 9/5 + 32
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'])
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['date'].dt.dayofyear
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tmax_avg'] = df[['tmax_vc', 'tmax_om', 'tmax_ms' ]].mean(axis=1)
# /var/folders/b9/fkf035lj1y786gv5xh300_qc0000gn/T/ipykernel_81338/3216503694.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tmin_avg'] = df[['tmin_ms']].mean(axis=1)
